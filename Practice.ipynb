# %%
course=['TCS','Wipro','Statistics']
course.remove('Wipro')

# %%
print(course)
# Out:
# ['TCS', 'Statistics']

# %%
stud=['M','N','Q','L','T','T']
stud.remove('T')
print(stud)
# Out:
# ['M', 'N', 'Q', 'L', 'T']

# %%
stud.pop()
print(stud)
# Out:
# ['M', 'N', 'Q', 'L']

# %%
stud.pop(1)
print(stud)
# Out:
# ['M', 'Q', 'L']

# %%
stud.delete[1]
print(stud)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 stud.delete[1]
#       2 print(stud)
#
# AttributeError: 'list' object has no attribute 'delete'

# %%
del stud[1]
print(stud)
# Out:
# ['M', 'L']

# %%
del stud
print(stud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 del stud
# ----> 2 print(stud)
#
# NameError: name 'stud' is not defined

# %%
l1=[1,2]
l1.clear()
print(l1)
# Out:
# []

# %%
movie=['a','b','c','d','e']
Film=movie.copy()
print(Film)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
l3=['a','b','c','d','e']
l4=[1,2,3,4,5,6]
l5=l3+l4
print(l5)
# Out:
# ['a', 'b', 'c', 'd', 'e', 1, 2, 3, 4, 5, 6]

# %%
film2=list(movie)
print(film2)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
print(max(l4))
# Out:
# 6

# %%
print(max(l3))
# Out:
# e
