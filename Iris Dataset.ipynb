# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape
# Out:
# (150, 6)

# %%
df['PetalWidthCm'].value_counts()
# Out:
# PetalWidthCm
# 0.2    28
# 1.3    13
# 1.5    12
# 1.8    12
# 1.4     8
# 2.3     8
# 0.4     7
# 1.0     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 1.1     3
# 2.4     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
(df['PetalWidthCm'].value_counts()).sort_values()
# Out:
# PetalWidthCm
# 0.6     1
# 0.5     1
# 1.7     2
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.6     4
# 1.9     5
# 1.2     5
# 2.0     6
# 0.1     6
# 2.1     6
# 0.3     7
# 1.0     7
# 0.4     7
# 1.4     8
# 2.3     8
# 1.5    12
# 1.8    12
# 1.3    13
# 0.2    28
# Name: count, dtype: int64

# %%
df.rename(columns={'PetalWidthCm':'petalwidthcm'})
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  petalwidthcm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df5=df.groupby('PetalWidthCm')
df5

# %%
df5.size()
# Out:
# PetalWidthCm
# 0.1     6
# 0.2    28
# 0.3     7
# 0.4     7
# 0.5     1
# 0.6     1
# 1.0     7
# 1.1     3
# 1.2     5
# 1.3    13
# 1.4     8
# 1.5    12
# 1.6     4
# 1.7     2
# 1.8    12
# 1.9     5
# 2.0     6
# 2.1     6
# 2.2     3
# 2.3     8
# 2.4     3
# 2.5     3
# dtype: int64

# %%
df5.first()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm          Species
# PetalWidthCm
# 0.1            10            4.9           3.1            1.5      Iris-setosa
# 0.2             1            5.1           3.5            1.4      Iris-setosa
# 0.3             7            4.6           3.4            1.4      Iris-setosa
# 0.4             6            5.4           3.9            1.7      Iris-setosa
# 0.5            24            5.1           3.3            1.7      Iris-setosa
# 0.6            44            5.0           3.5            1.6      Iris-setosa
# 1.0            58            4.9           2.4            3.3  Iris-versicolor
# 1.1            70            5.6           2.5            3.9  Iris-versicolor
# 1.2            74            6.1           2.8            4.7  Iris-versicolor
# 1.3            54            5.5           2.3            4.0  Iris-versicolor
# 1.4            51            7.0           3.2            4.7  Iris-versicolor
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(df['SepalLengthCm'])
plt.xlabel("Index")
plt.ylabel("Sepal Length (cm)")
plt.title("Line Plot of Sepal Length")
plt.show()

# %%
plt.figure()
plt.scatter(df['PetalLengthCm'], df['PetalWidthCm'])
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Scatter Plot: Petal Length vs Petal Width")
plt.show()

# %%
plt.figure()
plt.hist(df['SepalWidthCm'])
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequency")
plt.title("Histogram of Sepal Width")
plt.show()

# %%
avg_petal = df.groupby('Species')['PetalLengthCm'].mean()

plt.figure()
plt.bar(avg_petal.index, avg_petal.values)
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")
plt.title("Bar Chart: Avg Petal Length by Species")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.relplot(
    data=df,
    x="PetalLengthCm",
    y="PetalWidthCm",
    kind="scatter"
)
plt.show()

# %%
sns.scatterplot(
    data=df,
    x="SepalLengthCm",
    y="SepalWidthCm",
    hue="Species"
)
plt.show()

# %%
sns.lineplot(
    data=df,
    x=df.index,
    y="SepalLengthCm"
)
plt.show()

# %%
sns.histplot(
    data=df,
    x="PetalWidthCm"
)
plt.show()

# %%
sns.kdeplot(
    data=df,
    x="SepalLengthCm"
)
plt.show()

# %%
sns.boxplot(
    data=df,
    y="PetalLengthCm"
)
plt.show()

# %%
sns.violinplot(
    data=df,
    y="PetalWidthCm"
)
plt.show()

# %%
sns.barplot(
    data=df,
    x="Species",
    y="SepalLengthCm"
)
plt.show()

# %%
sns.countplot(
    data=df,
    x="Species"
)
plt.show()

# %%
corr = df[
    ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]
].corr()

sns.heatmap(corr, annot=True)
plt.show()

# %%
sns.pairplot(
    df,
    hue="Species"
)
plt.show()
