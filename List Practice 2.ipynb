# %%
#Data type
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling']
print(type(games))
# Out:
# <class 'list'>

# %%
#Indexing
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling']
print(games[2:5])
# Out:
# ['Tabletennis', 'Shortput', 'Javelline throw']

# %%
print(games[ :6])
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk']

# %%
#Negative Indexing
print(games[-3:-1])
# Out:
# ['Football', 'Rugby']

# %%
print(games[-6:-2])
# Out:
# ['Javelline throw', 'Hard disk', 'Badminton', 'Football']

# %%
#Append Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling']
games.append('Soccer')
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#Insert Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
games.insert(7,'Archery')
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Archery', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#Remove Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
games.remove('Shortput')
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#Pop Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
games.pop()
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling']

# %%
games.pop(5)
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Badminton', 'Football', 'Rugby', 'Wrestling']

# %%
#Delete Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
del games[4]
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#Extend Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
GaMes=['CrickeT','BasketbalL','TabletenniS','ShortpuT','Javelline throW','Hard disK','BadmintoN','FootbalL','RugbY','WrestlinG','SocceR']
games.extend(GaMes)
print(games)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer', 'CrickeT', 'BasketbalL', 'TabletenniS', 'ShortpuT', 'Javelline throW', 'Hard disK', 'BadmintoN', 'FootbalL', 'RugbY', 'WrestlinG', 'SocceR']

# %%
#Copy Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
games_list=games.copy()
print(games_list)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#List Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
Games_list=list(games)
print(Games_list)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer']

# %%
#Join two lists
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
GaMes=['CrickeT','BasketbalL','TabletenniS','ShortpuT','Javelline throW','Hard disK','BadmintoN','FootbalL','RugbY','WrestlinG','SocceR']
GAMES_LIST=games+GaMes
print(GAMES_LIST)
# Out:
# ['Cricket', 'Basketball', 'Tabletennis', 'Shortput', 'Javelline throw', 'Hard disk', 'Badminton', 'Football', 'Rugby', 'Wrestling', 'Soccer', 'CrickeT', 'BasketbalL', 'TabletenniS', 'ShortpuT', 'Javelline throW', 'Hard disK', 'BadmintoN', 'FootbalL', 'RugbY', 'WrestlinG', 'SocceR']

# %%
#Max Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
print(max(games))
# Out:
# Wrestling

# %%
#Min Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
print(min(games))
# Out:
# Badminton

# %%
#Clear Items
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
games.clear()
print(games)
# Out:
# []

# %%
games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
del games
print(games)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 games=['Cricket','Basketball','Tabletennis','Shortput','Javelline throw','Hard disk','Badminton','Football','Rugby','Wrestling','Soccer']
#       2 del games
# ----> 3 print(games)
#
# NameError: name 'games' is not defined
