# %%
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
print(type(student)
# Out:
# <class 'list'>

# %%
print(student[4:7])
# Out:
# ['Nidhi', 'Mehar', 'Nihal']

# %%
print(student[-8:-4])
# Out:
# ['Himanshu', 'Haadiya', 'Nidhi', 'Mehar']

# %%
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
student.append('Harshita')
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Aman', 'Ansh', 'Harshita']

# %%
student.insert(7,'Anup')
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Anup', 'Manav', 'Aman', 'Ansh', 'Harshita']

# %%
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
student.remove('Aman')
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Ansh']

# %%
students=['P','T','K','M','N','A']
student.extend(students)
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Ansh', 'P', 'T', 'K', 'M', 'N', 'A']

# %%
#pop method
student.pop()
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Ansh', 'P', 'T', 'K', 'M', 'N']

# %%
student.pop(11)
# Out:
# 'K'

# %%
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Ansh', 'P', 'T', 'M', 'N']

# %%
del student[5]
print(student)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Nihal', 'Manav', 'Ansh', 'P', 'T', 'M', 'N']

# %%
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
academy=student.copy()
print(academy)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Aman', 'Ansh']

# %%
academic=list(academy)
print(academic)
# Out:
# ['Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Aman', 'Ansh']

# %%
students=['P','T','K','M','N','A']
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
STUDENT=students+student
print(STUDENT)
# Out:
# ['P', 'T', 'K', 'M', 'N', 'A', 'Prastuti', 'Mayank', 'Himanshu', 'Haadiya', 'Nidhi', 'Mehar', 'Nihal', 'Manav', 'Aman', 'Ansh']

# %%
students=['P','T','K','M','N','A']
print(max(students))
# Out:
# T

# %%
students=['P','T','K','M','N','A']
print(min(students))
# Out:
# A

# %%
student=['Prastuti','Mayank','Himanshu','Haadiya','Nidhi','Mehar','Nihal','Manav','Aman','Ansh']
student.clear()
print(student)
# Out:
# []

# %%
del student
print(student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 del student
# ----> 2 print(student)
#
# NameError: name 'student' is not defined
